22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------- -------------------- 11.3/22.9 MB 4.2 MB/s eta 0:00:03
#    -------------------- ------------------- 11.5/22.9 MB 4.2 MB/s eta 0:00:03
#    -------------------- ------------------- 11.7/22.9 MB 4.2 MB/s eta 0:00:03
#    -------------------- ------------------- 11.8/22.9 MB 4.2 MB/s eta 0:00:03
#    -------------------- ------------------- 12.0/22.9 MB 4.2 MB/s eta 0:00:03
#    --------------------- ------------------ 12.2/22.9 MB 4.2 MB/s eta 0:00:03
#    --------------------- ------------------ 12.4/22.9 MB 4.2 MB/s eta 0:00:03
#    --------------------- ------------------ 12.6/22.9 MB 4.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 12.8/22.9 MB 4.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 12.9/22.9 MB 4.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 13.1/22.9 MB 4.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.4/22.9 MB 4.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.5/22.9 MB 4.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.7/22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------------ --------------- 13.9/22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------------ --------------- 14.1/22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------------ --------------- 14.2/22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.4/22.9 MB 4.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.6/22.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------- -------------- 14.8/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 14.9/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.1/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.3/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.4/22.9 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 15.6/22.9 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 15.8/22.9 MB 4.2 MB/s eta 0:00:02
#    --------------------------- ------------ 16.0/22.9 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 16.1/22.9 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 16.3/22.9 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 16.5/22.9 MB 4.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 16.7/22.9 MB 4.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 16.9/22.9 MB 4.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.1/22.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.2/22.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.4/22.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.5/22.9 MB 4.1 MB/s eta 0:00:02
#    ------------------------------ --------- 17.7/22.9 MB 4.1 MB/s eta 0:00:02
#    ------------------------------- -------- 18.0/22.9 MB 4.2 MB/s eta 0:00:02
#    ------------------------------- -------- 18.2/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.4/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.6/22.9 MB 4.1 MB/s eta 0:00:02
#    -------------------------------- ------- 18.7/22.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.8/22.9 MB 4.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.0/22.9 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 19.2/22.9 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 19.3/22.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.6/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.8/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 20.0/22.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.2/22.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.4/22.9 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.6/22.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 20.8/22.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 20.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 21.1/22.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 21.5/22.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 21.6/22.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 21.8/22.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 22.2/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.4/22.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  22.6/22.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 3.8 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.1 MB 8.6 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/6.1 MB 5.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.6/6.1 MB 5.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/6.1 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.1 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.2/6.1 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.4/6.1 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.5/6.1 MB 4.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/6.1 MB 4.5 MB/s eta 0:00:01
#    ------------ --------------------------- 1.9/6.1 MB 4.4 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.1 MB 4.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.2/6.1 MB 4.4 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.1 MB 4.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.1 MB 4.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.8/6.1 MB 4.4 MB/s eta 0:00:01
#    ------------------- -------------------- 2.9/6.1 MB 4.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.0/6.1 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.1 MB 4.1 MB/s eta 0:00:01
#    --------------------- ------------------ 3.2/6.1 MB 4.0 MB/s eta 0:00:01
#    --------------------- ------------------ 3.3/6.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.5/6.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.8/6.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 4.0/6.1 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.1/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.3/6.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.5/6.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 4.8/6.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.3/6.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 5.7/6.1 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 3.9 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.4 MB 5.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.4 MB 3.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 3.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 3.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 3.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.7 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Installing collected packages: shapely, pyproj, cligj, click-plugins, branca, folium, fiona, geopandas
# Successfully installed branca-0.7.2 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.6 folium-0.17.0 geopandas-0.14.4 pyproj-3.6.1 shapely-2.0.4

# %%
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point

# %%
url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.csv'
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             260 non-null    object
#  1   latitude         260 non-null    float64
#  2   longitude        260 non-null    float64
#  3   depth            260 non-null    float64
#  4   mag              260 non-null    float64
#  5   magType          260 non-null    object
#  6   nst              233 non-null    float64
#  7   gap              233 non-null    float64
#  8   dmin             227 non-null    float64
#  9   rms              260 non-null    float64
#  10  net              260 non-null    object
#  11  id               260 non-null    object
#  12  updated          260 non-null    object
#  13  place            260 non-null    object
#  14  type             260 non-null    object
#  15  horizontalError  232 non-null    float64
#  16  depthError       260 non-null    float64
#  17  magError         232 non-null    float64
#  18  magNst           233 non-null    float64
#  19  status           260 non-null    object
#  20  locationSource   260 non-null    object
#  21  magSource        260 non-null    object
# dtypes: float64(12), object(10)
# memory usage: 44.8+ KB

# %%
df.head()
# Out:
#                        time   latitude   longitude   depth   mag magType  \
# 0  2024-06-19T14:05:35.430Z  19.475166 -155.434662   0.180  2.47      ml
# 1  2024-06-19T12:43:16.810Z  19.275833 -155.406830  30.850  2.79      ml
# 2  2024-06-19T12:09:43.905Z  41.608500   71.183100  10.000  4.40      mb
# 3  2024-06-19T11:11:36.465Z  44.296600 -114.849400  13.257  2.90      ml
# 4  2024-06-19T10:48:18.275Z  -6.473900  147.678100  59.374  4.10      mb
#
#     nst    gap     dmin   rms  ...                   updated  \
# 0  56.0   35.0  0.04926  0.34  ...  2024-06-19T14:08:13.950Z
# 1  25.0  175.0  0.06065  0.15  ...  2024-06-19T12:45:53.240Z
# 2  27.0   98.0  0.13600  0.86  ...  2024-06-19T12:50:37.121Z
# 3  21.0   68.0  0.19000  0.36  ...  2024-06-19T11:33:24.040Z
# 4  14.0  174.0  2.95700  0.54  ...  2024-06-19T12:19:06.040Z
#
#                                         place        type horizontalError  \
# 0                  21 km W of Volcano, Hawaii  earthquake            0.32
# 1                  11 km NE of Pāhala, Hawaii  earthquake            0.71
# 2        19 km SSE of Kanysh-Kyya, Kyrgyzstan  earthquake            4.43
# 3                  11 km NE of Stanley, Idaho  earthquake            2.94
# 4  20 km WNW of Finschhafen, Papua New Guinea  earthquake           14.73
#
#   depthError  magError  magNst     status  locationSource magSource
# 0      0.540     0.290    30.0  automatic              hv        hv
# 1      0.630     0.490    17.0  automatic              hv        hv
# 2      1.932     0.126    18.0   reviewed              us        us
# 3      8.488     0.045    64.0   reviewed              us        us
# 4     12.892     0.158    11.0   reviewed              us        us
#
# [5 rows x 22 columns]

# %%
df.nunique()
# Out:
# time               260
# latitude           258
# longitude          259
# depth              212
# mag                 81
# magType              7
# nst                 89
# gap                131
# dmin               214
# rms                108
# net                 11
# id                 260
# updated            260
# place              235
# type                 1
# horizontalError    206
# depthError         230
# magError           161
# magNst              92
# status               2
# locationSource      11
# magSource           11
# dtype: int64

# %%
# Convert the DataFrame to a GeoDataFrame
# Create geometry column from latitude and longitude
geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
geo_df = gpd.GeoDataFrame(df, geometry=geometry)

# %%
print(geo_df.head())
# Out:
#                        time   latitude   longitude   depth   mag magType  \
# 0  2024-06-19T14:05:35.430Z  19.475166 -155.434662   0.180  2.47      ml
# 1  2024-06-19T12:43:16.810Z  19.275833 -155.406830  30.850  2.79      ml
# 2  2024-06-19T12:09:43.905Z  41.608500   71.183100  10.000  4.40      mb
# 3  2024-06-19T11:11:36.465Z  44.296600 -114.849400  13.257  2.90      ml
# 4  2024-06-19T10:48:18.275Z  -6.473900  147.678100  59.374  4.10      mb
#
#     nst    gap     dmin   rms  ...  \
# 0  56.0   35.0  0.04926  0.34  ...
# 1  25.0  175.0  0.06065  0.15  ...
# 2  27.0   98.0  0.13600  0.86  ...
# 3  21.0   68.0  0.19000  0.36  ...
# 4  14.0  174.0  2.95700  0.54  ...
#
#                                         place        type horizontalError  \
# 0                  21 km W of Volcano, Hawaii  earthquake            0.32
# 1                  11 km NE of Pāhala, Hawaii  earthquake            0.71
# 2        19 km SSE of Kanysh-Kyya, Kyrgyzstan  earthquake            4.43
# 3                  11 km NE of Stanley, Idaho  earthquake            2.94
# 4  20 km WNW of Finschhafen, Papua New Guinea  earthquake           14.73
#
#   depthError magError  magNst     status  locationSource  magSource  \
# 0      0.540    0.290    30.0  automatic              hv         hv
# 1      0.630    0.490    17.0  automatic              hv         hv
# 2      1.932    0.126    18.0   reviewed              us         us
# 3      8.488    0.045    64.0   reviewed              us         us
# 4     12.892    0.158    11.0   reviewed              us         us
#
#                       geometry
# 0  POINT (-155.43466 19.47517)
# 1  POINT (-155.40683 19.27583)
# 2    POINT (71.18310 41.60850)
# 3  POINT (-114.84940 44.29660)
# 4   POINT (147.67810 -6.47390)
#
# [5 rows x 23 columns]

# %%
mymap = folium.Map(location=[geo_df['latitude'].mean(), geo_df['longitude'].mean()], zoom_start=2)

# %%
for idx, row in geo_df.iterrows():
    folium.CircleMarker(location=[row['latitude'], row['longitude']],
                        radius=row['mag']*2,  # Adjust the size based on magnitude
                        color='red',
                        fill=True,
                        fill_color='red',
                        popup=f"Magnitude: {row['mag']}, Location: {row['place']}").add_to(mymap)

# %%
mymap.save('earthquakes_map.html')

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c160c0794b34e99da499cab5683977ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c160c0794b34e99da499cab5683977ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c160c0794b34e99da499cab5683977ab = L.map(
#                 &quot;map_c160c0794b34e99da499cab5683977ab&quot;,
#                 {
#                     center: [18.290563555039625, -33.01337648630977],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b44b2f01b23fdaf32175777b4c7794d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b44b2f01b23fdaf32175777b4c7794d4.addTo(map_c160c0794b34e99da499cab5683977ab);
#
#
#             var circle_marker_8e3556996a101d9bb4f9440d9e82abf2 = L.circleMarker(
#                 [19.4751663208008, -155.434661865234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.94, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c160c0794b34e99da499cab5683977ab);
#
#
#         var popup_a7bca3b8d5f600b73ce19ad855943f00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acb064dffe3d072b3c6d9c3a219181d4 = $(`&lt;div id=&quot;html_acb064dffe3d072b3c6d9c3a219181d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 2.47, Location: 21 km W of Volcano, Hawaii&lt;/div&gt;`)[0];
#                 popup_a7bca3b8d5f600b73ce19ad855943f00.setContent(html_acb064dffe3d072b3c6d9c3a219181d4);
#
#
#
#         circle_marker_8e3556996a101d9bb4f9440d9e82abf2.bindPopup(popup_a7bca3b8d5f600b73ce19ad855943f00)
#         ;
#
#
#
#
#             var circle_marker_af09d29dd56cc32a9fa71de761887ca6 = L.circleMarker(
#                 [19.2758331298828, -155.406829833984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.58, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c160c0794b34e99da499cab5683977ab);
#
#
#         var popup_92d8f750ab7746b1d308a161ef810757 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2b82bee135c6ae28e1f6a0bd2a2c2fc = $(`&lt;div id=&quot;html_e2b82bee135c6ae28e1f6a0bd2a2c2fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 2.79, Location: 11 km NE of Pāhala, Hawaii&lt;/div&gt;`)[0];
#                 popup_92d8f750ab7746b1d308a161ef810757.setContent(html_e2b82bee135c6ae28e1f6a0bd2a2c2fc);
#
#
#
#         circle_marker_af09d29dd56cc32a9fa71de761887ca6.bindPopup(popup_92d8f750ab7746b1d308a161ef810757)
#         ;
#
#
#
#
#             var circle_marker_95584e9dcc60747715a6a9cb44a536e7 = L.circleMarker(
#                 [41.6085, 71.1831],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c160c0794b34e99da499cab5683977ab);
#
#
#         var popup_3258b38332438d1689a9609422e7fc22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a45c15c194e69c431946e2196c849b1 = $(`&lt;div id=&quot;html_7a45c15c194e69c431946e2196c849b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 4.4, Location: 19 km SSE of Kanysh-Kyya, Kyrgyzstan&lt;/div&gt;`)[0];
#                 popup_3258b38332438d1689a9609422e7fc22.setContent(html_7a45c15c194e69c431946e2196c849b1);
#
#
#
#         circle_marker_95584e9dcc60747715a6a9cb44a536e7.bindPopup(popup_3258b38332438d1689a9609422e7fc22)
#         ;
#
#
#
#
#             var circle_marker_45630346b912ace5c379bdc49312ac2b = L.circleMarker(
#                 [44.2966, -114.8494],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;colo
